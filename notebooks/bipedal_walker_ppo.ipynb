# %% [markdown]
# # BipedalWalker-v2 - PPO

# %%
import os
import sys

sys.path.append(os.path.dirname(os.getcwd()))

from plotter import *

# %% [markdown]
# ## PPO Algorithm Specific Hyperparameters

# %% [markdown]
# ### Cliprange

# %%
experiments = get_experiments('../experiments/bipedal_walker/ppo/cliprange/params/',
                              '../experiments/bipedal_walker/ppo/cliprange/results/1234',
                              '../experiments/bipedal_walker/ppo/cliprange/results/1313',
                              '../experiments/bipedal_walker/ppo/cliprange/results/1337')
plot_auc_2d(experiments, min_val=-100, max_val=300, x='total_timesteps', y='eprewmean')
# Out:
# /home/filip/.conda/envs/inf5820/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Common Hyperparameters with respect to clipRange

# %% [markdown]
# ### cliprange - Gamma

# %%
experiments = get_experiments('../experiments/bipedal_walker/ppo/cliprange_gamma/params/',
                              '../experiments/bipedal_walker/ppo/cliprange_gamma/results/1234')
plot_heatmap(experiments,x='total_timesteps', y='eprewmean', min_val=-100, max_val=300)

# %%
experiments = get_experiments('../experiments/bipedal_walker/ppo/cliprange_lambda/params/',
                              '../experiments/bipedal_walker/ppo/cliprange_lambda/results/1234')
plot_heatmap(experiments,x='total_timesteps', y='eprewmean', min_val=-100, max_val=300)

# %%
experiments = get_experiments('../experiments/bipedal_walker/ppo/cliprange_entropy/params/',
                              '../experiments/bipedal_walker/ppo/cliprange_entropy/results/1234')
plot_heatmap(experiments,x='total_timesteps', y='eprewmean', min_val=-100, max_val=300)
